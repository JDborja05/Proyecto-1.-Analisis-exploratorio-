# %%
#Pregunta Smart - Cual es la vida util y el costo por posición de cada material por categoria?

#Obtener los datos

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel (r'C:\Users\Juanb\OneDrive\Escritorio\Maestria Ciencia de Datos\Harinera\BaseEjercicio.XLSX', sheet_name ='Sheet1')

#Anlizar estructura

print (df)
# Out:
#                   Grupo..                                  material  \
# 0      ESPARC. FLIAR COPA               ESPARCIBLE CANOLA LIFE 454G
# 1      ESPARC. FLIAR COPA               ESPARCIBLE CANOLA LIFE 454G
# 2      ESPARC. FLIAR COPA               ESPARCIBLE CANOLA LIFE 454G
# 3      ESPARC. FLIAR COPA               ESPARCIBLE CANOLA LIFE 454G
# 4      ESPARC. FLIAR COPA               ESPARCIBLE CANOLA LIFE 454G
# ..                    ...                                       ...
# 963     MEZCL. LISTAS IND  MEZCLA HDO PARA TORTA DE CHOCOLATE 2.5KG
# 964  SALSA PASTAS Y ADERE  OF SAL.BUC.BOL.480G GRA.P.CZ PEN.RE.500G
# 965  SALSA PASTAS Y ADERE  OF SAL.BUC.BOL.480G GRA.P.CZ PEN.RE.500G
# 966  SALSA PASTAS Y ADERE  OF SAL.BUC.BOL.480G GRA.P.CZ PEN.RE.500G
# 967  SALSA PASTAS Y ADERE  OF SAL.BUC.BOL.480G GRA.P.CZ PEN.RE.500G
#
#      %.vida.Util.Meses  Costo posicion
# 0                90.33        28843.74
# 1                90.78       942228.84
# ...

# %%
#Dicividir entre categoricas y numericas

print (df.dtypes)
# Out:
# Grupo..               object
# material              object
# %.vida.Util.Meses    float64
# Costo posicion       float64
# dtype: object

# %%
# Analisis univariado

df.describe (include = "all")
# Out:
#                    Grupo..                     material  %.vida.Util.Meses  \
# count                  968                          968         968.000000
# unique                   6                           57                NaN
# top     PREMEZCLA FAMILIAR  ESPARCIBLE CANOLA LIFE 907G                NaN
# freq                   360                           62                NaN
# mean                   NaN                          NaN          61.532355
# std                    NaN                          NaN         167.680311
# min                    NaN                          NaN       -4646.670000
# 25%                    NaN                          NaN          66.800000
# 50%                    NaN                          NaN          76.670000
# 75%                    NaN                          NaN          85.515000
# max                    NaN                          NaN         100.000000
#
#         Costo posicion
# count     9.680000e+02
# ...

# %%
df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 968 entries, 0 to 967
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Grupo..            968 non-null    object
#  1   material           968 non-null    object
#  2   %.vida.Util.Meses  968 non-null    float64
#  3   Costo posicion     968 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 30.4+ KB

# %%
df.head (100)
# Out:
#                Grupo..                     material  %.vida.Util.Meses  \
# 0   ESPARC. FLIAR COPA  ESPARCIBLE CANOLA LIFE 454G              90.33
# 1   ESPARC. FLIAR COPA  ESPARCIBLE CANOLA LIFE 454G              90.78
# 2   ESPARC. FLIAR COPA  ESPARCIBLE CANOLA LIFE 454G              90.33
# 3   ESPARC. FLIAR COPA  ESPARCIBLE CANOLA LIFE 454G              70.00
# 4   ESPARC. FLIAR COPA  ESPARCIBLE CANOLA LIFE 454G              83.00
# ..                 ...                          ...                ...
# 95  ESPARC. FLIAR COPA  ESPARCIBLE CANOLA LIFE 907G              83.33
# 96  ESPARC. FLIAR COPA  ESPARCIBLE CANOLA LIFE 907G              70.33
# 97  ESPARC. FLIAR COPA  ESPARCIBLE CANOLA LIFE 907G              70.33
# 98  ESPARC. FLIAR COPA  ESPARCIBLE CANOLA LIFE 907G              70.33
# 99  ESPARC. FLIAR COPA  ESPARCIBLE CANOLA LIFE 907G              70.33
#
#     Costo posicion
# 0         28843.74
# 1        942228.84
# 2        105905.58
# 3        120462.25
# ...

# %%
Unico_material = df['Grupo..'].unique ()
print(Unico_material)
# Out:
# ['ESPARC. FLIAR COPA' 'PREMEZCLA FAMILIAR' 'SALSA PASTAS Y ADERE' 'SYRUP'
#  'PROD. LISTOS' 'MEZCL. LISTAS IND']

# %%
plt.hist (df["Grupo.."], color = 'green', bins=20)
plt.title('Histograma cantidad de Grupos de articulo')
plt.ylabel('Cantidad de Grupos')
plt.xlabel('No. Grupos')
plt.xticks(fontsize = 7)
plt.show ()
